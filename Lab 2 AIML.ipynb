# %% [markdown]
# ## MLRAN Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('mlran_dataset_metadata.csv')

print("MLRAN METADATA FILE ANALYSIS")

# Dataset Properties
print("\n1. SIZE:")
print(f"   Total records: {df.shape[0]}")
print(f"   Total columns: {df.shape[1]}")
print(f"   Time span: {df['Year'].min()}-{df['Year'].max()}")

# Show columns of the data
print("\n2. COLUMNS IN METADATA:")
print(f"   Features: {list(df.columns)}")

# Show first few rows of the data
print("\n3. FIRST 5 ROWS:")
print(df.head())

# Data types
print("\n4. DATA TYPES:")
print(df.dtypes)

# Class Labels
print("\n5. CLASS LABELS:")
print("\n   Binary Classification:")
print(df['sample_type'].value_counts())
print("\n   Ransomware Families (Top 10):")
print(df['ransomware_family'].value_counts().head())
print("\n   Ransomware Types:")
print(df['ransomware_type'].value_counts())

# Summary
print("\n6. DATASET INFO:")
print(df.describe())

# Visualization
plt.figure(figsize=(10, 5))
df['ransomware_type'].value_counts().plot(kind='bar', color='blue')
plt.title('MLRan: Ransomware Types Distribution')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('mlran_types.png')
print("\n   Chart saved: mlran_types.png")
# Out:
# MLRAN METADATA FILE ANALYSIS
#
# 1. SIZE:
#    Total records: 4880
#    Total columns: 19
#    Time span: 1970-2024
#
# 2. COLUMNS IN METADATA:
#    Features: ['sample_id', 'sha256', 'sample_type', 'ransomware_family', 'family_label', 'ransomware_type', 'type_label', 'sha1', 'md5', 'extension', 'detections', 'source', 'timestamp', 'new_timestamp', 'old_timestamp', 'Year', 'first_submission_date', 'first_submission_date_converted', 'first_submission_date_year']
#
# 3. FIRST 5 ROWS:
#    sample_id                                             sha256  sample_type  \
# 0      10001  0068712434bda717df0d783b560b312854cb7dd4cf0789...            1
# 1      10002  00735e4ad3e9a9a5b3551dce371248327e74ef3c25edca...            1
# 2      10003  007a81ed76ca6d6e10584d90dee399b4ab98e59707688c...            1
# 3      10004  00bf847c9a53922a2b36348456ee0f1afff0eec705f221...            1
# 4      10005  00d786974e609adf93b29e6e86f7439074149e6cceabf3...            1
#
#   ransomware_family  family_label ransomware_type  type_label  \
# 0      cryptolocker             3          crypto           2
# 1        cryptowall            12          crypto           2
# 2      cryptolocker             3          crypto           2
# 3            kovter             9          locker           1
# 4            matsnu            11          locker           1
#
#                                        sha1                               md5  \
# 0  77d6871f350be911b2b5c3e16cc2c222c1887779  12be6e7241d2503f31fae01046e88d68
# 1  96fb7d2e3ad9fe434a66abb15b26dd4e40aa5d4b  aea8ab12edf294ddb2804d6618fdd247
# 2  8ecc04ce43c0c77978fa83169819e37a92110318  d5d010f8b2f145399a9638f457ff3990
# 3  0d9e3696c8516a89567ef712c612edacc3c3386b  d1510b299e8570afd352d20d516f6f48
# 4  b1e88afcd0ea38655005eb4a6247ce9355b518ba  bc5734bcc7e2d8e2e208ea483a09b158
#
#   extension detections   source   timestamp new_timestamp old_timestamp  Year  \
# 0       exe      30/56  elderan  2014:10:10    2014-10-10    2014:10:10  2014
# 1       exe      44/55  elderan  2015:04:02    2015-04-02    2015:04:02  2015
# 2       exe      28/52  elderan  2014:01:29    2014-01-29    2014:01:29  2014
# 3       exe      28/57  elderan  2015:08:09    2015-08-09    2015:08:09  2015
# 4       zip      42/55  elderan  1992:06:19    1992-06-19           NaN  1992
#
#    first_submission_date first_submission_date_converted  \
# 0             1413149304                      2014-10-12
# 1             1428563179                      2015-04-09
# 2             1401330145                      2014-05-29
# 3             1439196631                      2015-08-10
# 4             1416574498                      2014-11-21
#
#    first_submission_date_year
# 0                        2014
# 1                        2015
# 2                        2014
# 3                        2015
# 4                        2014
#
# 4. DATA TYPES:
# sample_id                           int64
# sha256                             object
# sample_type                         int64
# ransomware_family                  object
# family_label                        int64
# ransomware_type                    object
# type_label                          int64
# sha1                               object
# md5                                object
# extension                          object
# detections                         object
# source                             object
# timestamp                          object
# new_timestamp                      object
# old_timestamp                      object
# Year                                int64
# first_submission_date               int64
# first_submission_date_converted    object
# first_submission_date_year          int64
# dtype: object
#
# 5. CLASS LABELS:
#
#    Binary Classification:
# sample_type
# 0    2550
# 1    2330
# Name: count, dtype: int64
#
#    Ransomware Families (Top 10):
# ransomware_family
# goodware        2550
# pajetbin         134
# cryptolocker     104
# reveton           89
# locker            87
# Name: count, dtype: int64
#
#    Ransomware Types:
# ransomware_type
# goodware    2550
# crypto      1140
# raas         468
# modern       449
# locker       273
# Name: count, dtype: int64
#
# 6. DATASET INFO:
#           sample_id  sample_type  family_label   type_label         Year  \
# count   4880.000000  4880.000000   4880.000000  4880.000000  4880.000000
# mean   12865.948361     0.477459     11.670287     1.178893  2010.095697
# std     1725.296148     0.499543     18.306675     1.391482    10.808667
# min    10001.000000     0.000000      0.000000     0.000000  1970.000000
# 25%    11269.750000     0.000000      0.000000     0.000000  2004.000000
# 50%    13119.500000     0.000000      0.000000     0.000000  2014.000000
# 75%    14397.250000     1.000000     17.000000     2.000000  2018.000000
# max    15695.000000     1.000000     65.000000     4.000000  2024.000000
#
#        first_submission_date  first_submission_date_year
# count           4.880000e+03                 4880.000000
# mean            1.517920e+09                 2017.588115
# std             1.320386e+08                    4.167534
# min             1.162439e+09                 2006.000000
# 25%             1.417390e+09                 2014.000000
# 50%             1.521667e+09                 2018.000000
# 75%             1.635929e+09                 2021.000000
# max             1.721872e+09                 2024.000000
#
#    Chart saved: mlran_types.png

# %% [markdown]
# ## JS Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('JSVulnerabilitydataSet-1.0.csv')
print("JAVASCRIPT VULNERABILITY DATASET PROPERTIES")

# Property A: SIZE
print("\n1. SIZE:")
print(f"   Total functions: {len(df):,}")
if 'label' in df.columns:
    print(f"   Vulnerable functions: {(df['label']==1).sum():,}")
    print(f"   Non-vulnerable functions: {(df['label']==0).sum():,}")
else:
    print("   Label column distribution:")
    print(f"   {df.iloc[:, -1].value_counts()}")

# Property B: DIMENSION
print("\n2. DIMENSION:")
print(f"   Total features: {df.shape[1]}")
print(f"   Sample features: {list(df.columns[:10])}")

# Property D: DATA TYPES
print("\n4. DATA TYPES:")
print(df.dtypes)

# Property E: CLASS LABELS
print("\n5. CLASS LABELS:")
print("\n   Binary Classification:")
if 'label' in df.columns:
    label_counts = df['label'].value_counts().sort_index()
    print(f"   Non-vulnerable (0): {label_counts.get(0, 0):,}")
    print(f"   Vulnerable (1): {label_counts.get(1, 0):,}")
else:
    print(df.iloc[:, -1].value_counts())

# Basic statistics
print("\n6. FEATURE STATISTICS:")
print(df.describe().iloc[:, :5])  # Show first 5 features
# Out:
# JAVASCRIPT VULNERABILITY DATASET PROPERTIES
#
# 1. SIZE:
#    Total functions: 12,125
#    Label column distribution:
#    Vuln
# 0    10629
# 1     1496
# Name: count, dtype: int64
#
# 2. DIMENSION:
#    Total features: 44
#    Sample features: ['name', 'longname', 'path', 'full_repo_path', 'line', 'column', 'endline', 'endcolumn', 'CC', 'CCL']
#
# 4. DATA TYPES:
# name               object
# longname           object
# path               object
# full_repo_path     object
# line                int64
# column              int64
# endline             int64
# endcolumn           int64
# CC                float64
# CCL                 int64
# CCO                 int64
# CI                  int64
# CLC               float64
# CLLC                int64
# McCC                int64
# NL                  int64
# NLE                 int64
# CD                float64
# CLOC                int64
# DLOC                int64
# TCD               float64
# TCLOC               int64
# LLOC                int64
# LOC                 int64
# NOS                 int64
# NUMPAR              int64
# TLLOC               int64
# TLOC                int64
# TNOS                int64
# HOR_D               int64
# HOR_T               int64
# HON_D               int64
# HON_T               int64
# HLEN                int64
# HVOC                int64
# HDIFF             float64
# HVOL              float64
# HEFF              float64
# HBUGS             float64
# HTIME             float64
# CYCL                int64
# PARAMS              int64
# CYCL_DENS         float64
# Vuln                int64
# dtype: object
#
# 5. CLASS LABELS:
#
#    Binary Classification:
# Vuln
# 0    10629
# 1     1496
# Name: count, dtype: int64
#
# 6. FEATURE STATISTICS:
#                line        column       endline     endcolumn            CC
# count  12125.000000  12125.000000  12125.000000  12125.000000  12125.000000
# mean    1235.934928   3319.142021   1255.861856   3332.408825      0.128959
# std     2032.526922   7540.253073   2037.516290   7556.573589      0.330502
# min        1.000000      0.000000      1.000000      1.000000      0.000000
# 25%       26.000000     14.000000     32.000000      3.000000      0.000000
# 50%      375.000000     30.000000    399.000000      5.000000      0.000000
# 75%     1291.000000     75.000000   1323.000000    108.000000      0.000000
# max    10557.000000  32523.000000  10587.000000  31944.000000      1.000000
